# %%
# Replacing
image = Image.new('L', (imagewidth, imageheight), color=backcolor)

# With
image = Image.new('RGB', (imagewidth, imageheight), color=(0, 0, 0))
pixelset = image.load()



# and for red text
pixelset[scaledx, scaledy] = (255, 0, 0)
Instead of
pixelset[scaledx, scaledy] = forecolor
